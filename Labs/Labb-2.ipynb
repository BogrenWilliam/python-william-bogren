# %%
# Huvuduppgift
from math import sqrt
import re
import string
import math
import matplotlib.pyplot as plt

with open("../data/datapoints.txt") as f_read:
    data_points = f_read.readlines()  
    data_points.pop(0) # "pop" returns the removed value and 1st line with (0)

    PokemonWidth = []
    PokemonHeight = []
    PokemonLabel = []


    
    for line in data_points: # Changes the text and places in three elements, for each step
        

        Width, Height, Label = [float(1) for i in line.split (",")]

        PokemonWidth.append(Width) # Puts > PokemonWidth
        PokemonHeight.append(Height) # Puts > PokemonHeight
        PokemonLabel.append(Label) # Puts > PokemonLabel




def Pokemon_plot(): # Function plot (x, y and Labels for both and also title)

    for (Widthplot, Heightplot, Labelplot) in zip(PokemonWidth, PokemonHeight,PokemonLabel): 
        if Labelplot == 0: 
            color_of_Pokemon = "Blue"
        else: 
            color_of_Pokemon = "Red"
        plt.plot(Widthplot, Heightplot, Labelplot,"o", markerfacecolor=color_of_Pokemon, markersize = 5)
plt.grid()
    
    



Pokemon_plot()

with open ("../Data/testpoints.txt") as file:
    test_points = file.readlines()
    test_points = test_points[1:]
    x_Width = []
    y_Height = []
    
    for test_points_number in test_points:
        test_points_number = test_points_number[4:-2]
        print(test_points_number)
        
        x_Width.append(test_points_number.split(', ')[0])

        y_Height.append(test_points_number.split(', ')[1])


while True: 
    user_input_Width = input("Write the width of the poke:")
    try:
        userinput_Width = float(user_input_Width)
        if not 0 <= userinput_Width <= 100:
            raise ValueError(f"No charachter or negative number. {user_input_Width} is not a correct format..")
        break
    except ValueError as err:
        print(f"use number istead of chatacter")



while True:
    user_input_Length = input(f"Enter the height of  the poke: ")
    try:
        user_input_Length = float(user_input_Length)
        if not 0 <= user_input_Length <= 100:
           raise ValueError(f"No charachter or negative numbers. {user_input_Length} is not a correct fornat.. ")
        break
    except ValueError as err: 
        print(f"Use numbers instead of charachters ") # Plots the point the user enters which makes it go black


dist_list = [] # Distance calcultor
for Width, Height, Label in zip(PokemonWidth, PokemonHeight, PokemonLabel):
        distance = math.sqrt((user_input_Width - Width)**2) + ((user_input_Height- Height)**2)
        dist_list.append([distance, Label])


dist_list.sort()

pike_dist = []
pichu_dist = []

majority_decision = 0 
for i in range(10):
# Out:
# 25, 32
# 24.2, 31.5
# 22, 34
# 20.5, 34
# ['25', '24.2', '22', '20.5']
# ['32', '31.5', '34', '34']
# ...

# %%
# Exercise 1

import math
